# %% [markdown]
# <a href="https://colab.research.google.com/github/hdspgroup/SeismicEnhancement/blob/main/GuajiraOff.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Geological Modeling**
#
# Guajira Offshore geological model
#
# Open this notebook in Jupyter after doing the installation of gempy libraries

# %%
import gempy as gp
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import pyvista
import gempy_viewer as gpv
import gempy as plot_2d

# %%
geo_model: gp.data.GeoModel = gp.create_geomodel(
    project_name='Modelo_1',
    extent=[0, 30000, 0, 2000, -15000, 0],
    resolution=[20, 20, 20],  # * Here we define the resolution of the voxels
    importer_helper=gp.data.ImporterHelper(
        path_to_orientations= "guajira_orientaciones.txt",
        path_to_surface_points= "SUPERFICIES_GUAOFF.txt",
    )
)

# %%
geo_model.surface_points
# Out:
# SurfacePointsTable(data=
# [(  684.92, 1000.,  -5186.97,  87203837, 0.),
#  (  906.67, 1000.,  -5584.67,  87203837, 0.),
#  ( 1564.49, 1000.,  -6884.73,  87203837, 0.),
#  ( 2260.92, 1000.,  -8458.19,  87203837, 0.),
#  ( 3588.05, 1000., -11591.88,  87203837, 0.),
#  ( 3941.51, 1000., -12426.5 ,  87203837, 0.),
#  (29884.19, 1000.,  -4525.09, 127946233, 0.),
#  (28997.64, 1000.,  -5123.23, 127946233, 0.),
#  (28565.64, 1000.,  -5460.54, 127946233, 0.),
#  (26759.8 , 1000.,  -6569.92, 127946233, 0.),
#  (23972.93, 1000.,  -8281.97, 127946233, 0.),
#  (18379.25, 1000., -11344.86, 127946233, 0.),
#  (15162.35, 1000., -13106.31, 127946233, 0.),
#  (24392.15, 1000., -12133.25, 252221171, 0.),
#  (29803.57, 1000.,  -9125.09, 252221171, 0.),
#  (  170.32, 1000.,  -5653.36, 334279139, 0.),
#  (  906.67, 1000.,  -5584.67, 334279139, 0.),
#  ( 1564.49, 1000.,  -6884.73, 334279139, 0.),
#  ( 1770.66, 1000.,  -6884.73, 334279139, 0.),
#  ( 2187.93, 1000.,  -6997.57, 334279139, 0.),
#  ( 3935.55, 1000.,  -7704.01, 334279139, 0.),
#  ( 5621.95, 1000.,  -8221.18, 334279139, 0.),
#  ( 6098.13, 1000.,  -8221.18, 334279139, 0.),
#  ( 6662.67, 1000.,  -8074.01, 334279139, 0.),
#  ( 7777.02, 1000.,  -7593.23, 334279139, 0.),
#  ( 9104.46, 1000.,  -7057.55, 334279139, 0.),
#  ( 9537.83, 1000.,  -7008.92, 334279139, 0.),
#  (10367.17, 1000.,  -6818.1 , 334279139, 0.),
#  (10912.27, 1000.,  -6740.57, 334279139, 0.),
#  (11296.08, 1000.,  -6740.57, 334279139, 0.),
#  (11645.17, 1000.,  -6781.05, 334279139, 0.),
#  (13210.24, 1000.,  -6806.28, 334279139, 0.),
#  (14104.46, 1000.,  -6781.03, 334279139, 0.),
#  (14549.98, 1000.,  -6736.69, 334279139, 0.),
#  (15361.96, 1000.,  -6736.69, 334279139, 0.),
#  (16425.8 , 1000.,  -6827.21, 334279139, 0.),
#  (16950.41, 1000.,  -6854.19, 334279139, 0.),
#  (17879.25, 1000.,  -6813.77, 334279139, 0.),
#  (18263.06, 1000.,  -6769.44, 334279139, 0.),
#  (18975.79, 1000.,  -6734.6 , 334279139, 0.),
#  (19421.32, 1000.,  -6734.6 , 334279139, 0.),
#  (20094.43, 1000.,  -6665.21, 334279139, 0.),
#  (20680.05, 1000.,  -6634.25, 334279139, 0.),
#  (21580.75, 1000.,  -6634.25, 334279139, 0.),
#  (22553.58, 1000.,  -6590.1 , 334279139, 0.),
#  (23357.85, 1000.,  -6590.1 , 334279139, 0.),
#  (24398.67, 1000.,  -6590.1 , 334279139, 0.),
#  (24680.26, 1000.,  -6563.02, 334279139, 0.),
#  (25106.5 , 1000.,  -6563.02, 334279139, 0.),
#  (25830.38, 1000.,  -6614.38, 334279139, 0.),
#  (  834.48, 1000.,  -5309.36, 489343825, 0.),
#  ( 1287.84, 1000.,  -5224.64, 489343825, 0.),
#  ( 1809.39, 1000.,  -5255.95, 489343825, 0.),
#  ( 2435.99, 1000.,  -5366.45, 489343825, 0.),
#  ( 3163.  , 1000.,  -5734.56, 489343825, 0.),
#  ( 3770.78, 1000.,  -5978.26, 489343825, 0.),
#  ( 4352.69, 1000.,  -6113.03, 489343825, 0.),
#  ( 5083.67, 1000.,  -6174.51, 489343825, 0.),
#  ( 6120.04, 1000.,  -6174.51, 489343825, 0.),
#  ( 6878.47, 1000.,  -6076.69, 489343825, 0.),
#  ( 7986.88, 1000.,  -5892.08, 489343825, 0.),
#  ( 8683.52, 1000.,  -5776.05, 489343825, 0.),
#  ( 9124.33, 1000.,  -5776.05, 489343825, 0.),
#  ( 9471.63, 1000.,  -5805.04, 489343825, 0.),
#  (10215.16, 1000.,  -5805.04, 489343825, 0.),
#  (11002.13, 1000.,  -5633.4 , 489343825, 0.),
#  (11529.75, 1000.,  -5570.44, 489343825, 0.),
#  (12261.3 , 1000.,  -5537.21, 489343825, 0.),
#  (13036.78, 1000.,  -5395.47, 489343825, 0.),
#  (13355.29, 1000.,  -5367.71, 489343825, 0.),
#  (13979.34, 1000.,  -5336.25, 489343825, 0.),
#  (15015.83, 1000.,  -5336.25, 489343825, 0.),
#  (15697.28, 1000.,  -5336.25, 489343825, 0.),
#  (16256.52, 1000.,  -5239.65, 489343825, 0.),
#  (18111.57, 1000.,  -5215.42, 489343825, 0.),
#  (19274.94, 1000.,  -5152.51, 489343825, 0.),
#  (20102.82, 1000.,  -5180.33, 489343825, 0.),
#  (21899.35, 1000.,  -5147.04, 489343825, 0.),
#  (23311.27, 1000.,  -5089.42, 489343825, 0.),
#  (23962.81, 1000.,  -5031.92, 489343825, 0.),
#  (25414.95, 1000.,  -4987.56, 489343825, 0.),
#  (26121.19, 1000.,  -4916.82, 489343825, 0.),
#  (27235.73, 1000.,  -4916.82, 489343825, 0.),
#  (27889.98, 1000.,  -4831.07, 489343825, 0.),
#  (28375.62, 1000.,  -4831.07, 489343825, 0.),
#  (  113.5 , 1000.,  -5115.89, 521177335, 0.),
#  (  419.45, 1000.,  -5159.51, 521177335, 0.),
#  (  787.12, 1000.,  -5099.7 , 521177335, 0.),
#  ( 1265.93, 1000.,  -5019.95, 521177335, 0.),
#  ( 1636.45, 1000.,  -5019.95, 521177335, 0.),
#  ( 2568.43, 1000.,  -5019.95, 521177335, 0.),
#  ( 2857.28, 1000.,  -4974.35, 521177335, 0.),
#  ( 3452.95, 1000.,  -5017.08, 521177335, 0.),
#  ( 4716.82, 1000.,  -5017.08, 521177335, 0.),
#  ( 6190.33, 1000.,  -5017.08, 521177335, 0.),
#  ( 6642.22, 1000.,  -5017.08, 521177335, 0.),
#  ( 7967.52, 1000.,  -4934.21, 521177335, 0.),
#  ( 9114.49, 1000.,  -4934.21, 521177335, 0.),
#  (10206.08, 1000.,  -4994.04, 521177335, 0.),
#  (10495.18, 1000.,  -4994.04, 521177335, 0.),
#  (10996.8 , 1000.,  -4928.64, 521177335, 0.),
#  (11618.12, 1000.,  -4997.  , 521177335, 0.),
#  (12405.68, 1000.,  -4997.  , 521177335, 0.),
#  (13685.38, 1000.,  -4997.  , 521177335, 0.),
#  (14701.96, 1000.,  -4997.  , 521177335, 0.),
#  (15958.86, 1000.,  -4899.95, 521177335, 0.),
#  (17091.88, 1000.,  -4812.47, 521177335, 0.),
#  (17764.44, 1000.,  -4812.47, 521177335, 0.),
#  (19216.14, 1000.,  -4812.47, 521177335, 0.),
#  (19814.66, 1000.,  -4757.48, 521177335, 0.),
#  (20444.53, 1000.,  -4805.9 , 521177335, 0.),
#  (22144.88, 1000.,  -4805.9 , 521177335, 0.),
#  (23521.22, 1000.,  -4739.56, 521177335, 0.),
#  (24091.1 , 1000.,  -4739.56, 521177335, 0.),
#  (25131.71, 1000.,  -4739.56, 521177335, 0.),
#  (26249.  , 1000.,  -4639.14, 521177335, 0.),
#  (27405.98, 1000.,  -4586.99, 521177335, 0.),
#  (29012.18, 1000.,  -4514.59, 521177335, 0.),
#  (29714.75, 1000.,  -4482.93, 521177335, 0.),
#  (29939.81, 1000.,  -4482.93, 521177335, 0.),
#  (   76.16, 1000.,  -4533.16, 631065127, 0.),
#  ( 1053.97, 1000.,  -4533.16, 631065127, 0.),
#  ( 1902.22, 1000.,  -4455.47, 631065127, 0.),
#  ( 2821.14, 1000.,  -4371.3 , 631065127, 0.),
#  ( 3510.22, 1000.,  -4371.3 , 631065127, 0.),
#  ( 4572.05, 1000.,  -4396.77, 631065127, 0.),
#  ( 5454.84, 1000.,  -4396.77, 631065127, 0.),
#  ( 6190.83, 1000.,  -4342.97, 631065127, 0.),
#  ( 6784.82, 1000.,  -4342.97, 631065127, 0.),
#  ( 8032.59, 1000.,  -4342.97, 631065127, 0.),
#  ( 9034.46, 1000.,  -4375.87, 631065127, 0.),
#  ( 9877.81, 1000.,  -4375.87, 631065127, 0.),
#  (11165.75, 1000.,  -4403.61, 631065127, 0.),
#  (11702.58, 1000.,  -4465.91, 631065127, 0.),
#  (13276.26, 1000.,  -4465.91, 631065127, 0.),
#  (14008.  , 1000.,  -4465.91, 631065127, 0.),
#  (14946.59, 1000.,  -4412.34, 631065127, 0.),
#  (16016.29, 1000.,  -4375.89, 631065127, 0.),
#  (16669.16, 1000.,  -4344.74, 631065127, 0.),
#  (17889.23, 1000.,  -4344.74, 631065127, 0.),
#  (18247.7 , 1000.,  -4303.12, 631065127, 0.),
#  (19595.98, 1000.,  -4303.12, 631065127, 0.),
#  (20798.8 , 1000.,  -4268.55, 631065127, 0.),
#  (21320.05, 1000.,  -4223.55, 631065127, 0.),
#  (22864.68, 1000.,  -4090.21, 631065127, 0.),
#  (24317.04, 1000.,  -3964.84, 631065127, 0.),
#  (26036.79, 1000.,  -3824.92, 631065127, 0.),
#  (27944.72, 1000.,  -3738.5 , 631065127, 0.),
#  (29004.25, 1000.,  -3690.51, 631065127, 0.),
#  (29446.3 , 1000.,  -3638.62, 631065127, 0.),
#  (29936.99, 1000.,  -3638.62, 631065127, 0.),
#  (   92.26, 1000.,  -3080.53, 722822393, 0.),
#  ( 1060.94, 1000.,  -3080.53, 722822393, 0.),
#  ( 2584.79, 1000.,  -3214.7 , 722822393, 0.),
#  ( 4015.34, 1000.,  -3214.7 , 722822393, 0.),
#  ( 6657.04, 1000.,  -3214.7 , 722822393, 0.),
#  ( 8255.63, 1000.,  -3059.8 , 722822393, 0.),
#  ( 8891.01, 1000.,  -3059.8 , 722822393, 0.),
#  (10329.51, 1000.,  -3118.41, 722822393, 0.),
#  (11918.93, 1000.,  -3118.41, 722822393, 0.),
#  (12647.49, 1000.,  -3081.23, 722822393, 0.),
#  (14326.57, 1000.,  -3046.65, 722822393, 0.),
#  (14871.65, 1000.,  -3046.65, 722822393, 0.),
#  (16072.22, 1000.,  -3001.29, 722822393, 0.),
#  (16558.81, 1000.,  -3001.29, 722822393, 0.),
#  (17167.71, 1000.,  -3001.29, 722822393, 0.),
#  (17752.91, 1000.,  -3001.29, 722822393, 0.),
#  (19112.23, 1000.,  -3001.29, 722822393, 0.),
#  (20211.73, 1000.,  -3001.29, 722822393, 0.),
#  (22241.35, 1000.,  -2957.37, 722822393, 0.),
#  (24563.75, 1000.,  -2845.44, 722822393, 0.),
#  (25480.78, 1000.,  -2791.64, 722822393, 0.),
#  (26454.92, 1000.,  -2791.64, 722822393, 0.),
#  (27983.39, 1000.,  -2727.1 , 722822393, 0.),
#  (28636.61, 1000.,  -2689.15, 722822393, 0.),
#  (29438.52, 1000.,  -2689.15, 722822393, 0.),
#  (29863.7 , 1000.,  -2689.15, 722822393, 0.),
#  (  120.22, 1000.,  -2103.4 , 804654204, 0.),
#  (  647.74, 1000.,  -2103.4 , 804654204, 0.),
#  ( 1304.65, 1000.,  -2103.4 , 804654204, 0.),
#  ( 1946.31, 1000.,  -2164.14, 804654204, 0.),
#  ( 2494.41, 1000.,  -2201.11, 804654204, 0.),
#  ( 2987.09, 1000.,  -2201.11, 804654204, 0.),
#  ( 3626.83, 1000.,  -2201.11, 804654204, 0.),
#  ( 4332.75, 1000.,  -2201.11, 804654204, 0.),
#  ( 5452.79, 1000.,  -2155.82, 804654204, 0.),
#  ( 6366.42, 1000.,  -2118.88, 804654204, 0.),
#  ( 7126.15, 1000.,  -2088.16, 804654204, 0.),
#  ( 8119.03, 1000.,  -2015.25, 804654204, 0.),
#  ( 9137.48, 1000.,  -1975.65, 804654204, 0.),
#  ( 9997.03, 1000.,  -1975.65, 804654204, 0.),
#  (10838.12, 1000.,  -1975.65, 804654204, 0.),
#  (11769.09, 1000.,  -1975.65, 804654204, 0.),
#  (12599.08, 1000.,  -1975.65, 804654204, 0.),
#  (13189.32, 1000.,  -1975.65, 804654204, 0.),
#  (14319.78, 1000.,  -1975.65, 804654204, 0.),
#  (16248.93, 1000.,  -1921.13, 804654204, 0.),
#  (17196.95, 1000.,  -1894.34, 804654204, 0.),
#  (18322.27, 1000.,  -1862.54, 804654204, 0.),
#  (19781.95, 1000.,  -1827.21, 804654204, 0.),
#  (20584.31, 1000.,  -1827.21, 804654204, 0.),
#  (21914.16, 1000.,  -1775.28, 804654204, 0.),
#  (24179.3 , 1000.,  -1646.36, 804654204, 0.),
#  (25170.59, 1000.,  -1591.15, 804654204, 0.),
#  (25913.78, 1000.,  -1591.15, 804654204, 0.),
#  (26349.31, 1000.,  -1531.25, 804654204, 0.),
#  (27698.19, 1000.,  -1531.25, 804654204, 0.),
#  (28695.77, 1000.,  -1531.25, 804654204, 0.),
#  (29468.08, 1000.,  -1531.25, 804654204, 0.),
#  (29896.95, 1000.,  -1481.  , 804654204, 0.)],
# name_id_map={'Falla1': 87203837, 'Falla2': 127946233, 'Falla3': 252221171, 'S1': 334279139, 'S2': 489343825, 'S3': 521177335, 'S4': 631065127, 'S5': 722822393, 'S6': 804654204, 'basement': 56241757})

# %%
geo_model.orientations
# Out:
# OrientationsTable(data=
# [( 2260.92, 1000.,  -8458.19,  1.88,  0.  , 0.68,  87203837, 0.01),
#  ( 3941.51, 1000., -12426.5 ,  1.88,  0.  , 0.68,  87203837, 0.01),
#  (28565.64, 1000.,  -5460.54, -1.15, -0.  , 1.64, 127946233, 0.01),
#  (15162.35, 1000., -13106.31, -1.72, -0.  , 2.46, 127946233, 0.01),
#  (24392.15, 1000., -12133.25, -1.15, -0.  , 1.64, 252221171, 0.01),
#  (17879.25, 1000.,  -6813.77,  0.  ,  0.17, 1.99, 334279139, 0.01),
#  ( 3163.  , 1000.,  -5734.56,  0.  ,  0.09, 1.  , 489343825, 0.01),
#  ( 7967.52, 1000.,  -4934.21,  0.  ,  0.09, 1.  , 521177335, 0.01),
#  (16016.29, 1000.,  -4375.89,  0.  ,  0.09, 1.  , 631065127, 0.01),
#  (16072.22, 1000.,  -3001.29,  0.  ,  0.09, 1.  , 722822393, 0.01),
#  (14319.78, 1000.,  -1975.65,  0.  ,  0.09, 1.  , 804654204, 0.01)],
# name_id_map=None)

# %%
geo_model.structural_frame
# Out:
# StructuralFrame(
# 	structural_groups=[
# StructuralGroup(
# 	name=default_formation,
# 	structural_relation=StackRelationType.ERODE,
# 	elements=[
# Element(
# 	name=Falla1,
# 	color=#015482,
# 	is_active=True
# ),
# Element(
# 	name=Falla2,
# 	color=#9f0052,
# 	is_active=True
# ),
# Element(
# 	name=Falla3,
# 	color=#ffbe00,
# 	is_active=True
# ),
# Element(
# 	name=S1,
# 	color=#728f02,
# 	is_active=True
# ),
# Element(
# 	name=S2,
# 	color=#443988,
# 	is_active=True
# ),
# Element(
# 	name=S3,
# 	color=#ff3f20,
# 	is_active=True
# ),
# Element(
# 	name=S4,
# 	color=#5DA629,
# 	is_active=True
# ),
# Element(
# 	name=S5,
# 	color=#b271d0,
# 	is_active=True
# ),
# Element(
# 	name=S6,
# 	color=#72e54a,
# 	is_active=True
# )
# ]
# )
# ],
# 	fault_relations=
# [[False]],

# %%
gp.map_stack_to_surfaces(
    gempy_model=geo_model,
    mapping_object=  # TODO: This mapping I do not like it too much. We should be able to do it passing the data objects directly
    {
        "Fault_Series": ('Falla1','Falla2','Falla3'),
        "Strat_Series": ('S6', 'S5','S4','S3','S2','S1')
    }
)

geo_model.structural_frame  # Display the resulting structural frame

# %%
gp.set_is_fault(
    frame=geo_model.structural_frame,
    fault_groups=['Fault_Series']
)
# Out:
# StructuralFrame(
# 	structural_groups=[
# StructuralGroup(
# 	name=Fault_Series,
# 	structural_relation=StackRelationType.FAULT,
# 	elements=[
# Element(
# 	name=Falla1,
# 	color=#527682,
# 	is_active=True
# ),
# Element(
# 	name=Falla2,
# 	color=#527682,
# 	is_active=True
# ),
# Element(
# 	name=Falla3,
# 	color=#527682,
# 	is_active=True
# )
# ]
# ),
# StructuralGroup(
# 	name=Strat_Series,
# 	structural_relation=StackRelationType.ERODE,
# 	elements=[
# Element(
# 	name=S6,
# 	color=#72e54a,
# 	is_active=True
# ),
# Element(
# 	name=S5,
# 	color=#b271d0,
# 	is_active=True
# ),
# Element(
# 	name=S4,
# 	color=#5DA629,
# 	is_active=True
# ),
# Element(
# 	name=S3,
# 	color=#ff3f20,
# 	is_active=True
# ),
# Element(
# 	name=S2,
# 	color=#443988,
# 	is_active=True
# ),
# Element(
# 	name=S1,
# 	color=#728f02,
# 	is_active=True
# )
# ]
# )
# ],
# 	fault_relations=
# [[False,  True],
#  [False, False]],

# %%
geo_model.grid

# %%
plot= gpv.plot_2d(geo_model, show_lith=True, show_boundaries=False)
# Out:
# C:\Users\silva\anaconda3\envs\gempy\lib\site-packages\gempy_viewer\API\_plot_2d_API.py:170: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.fig.show()

# %%
gpv.plot_3d(geo_model, image=True, plotter_type='basic')

# %%
geo_model.interpolation_options
# Out:
# InterpolationOptions(kernel_options={'range': 5, 'c_o': 10, 'uni_degree': 1, 'i_res': 4, 'gi_res': 2, 'number_dimensions': 3, 'kernel_function': <AvailableKernelFunctions.cubic: KernelFunction(base_function=<function cubic_function at 0x0000028FF0B87250>, derivative_div_r=<function cubic_function_p_div_r at 0x0000028FF0B87640>, second_derivative=<function cubic_function_a at 0x0000028FF0B876D0>, consume_sq_distance=False)>, 'compute_condition_number': False, 'kernel_solver': <Solvers.DEFAULT: 1>}, number_octree_levels=1, current_octree_level=0, compute_scalar_gradient=False, dual_contouring=True, dual_contouring_masking_options=DualContouringMaskingOptions.INTERSECT, dual_contouring_fancy=True, debug=True, debug_water_tight=False, _number_octree_levels_surface=4)

# %%
sol = gp.compute_model(geo_model)
sol
# Out:
# Setting Backend To: AvailableBackends.numpy
# C:\Users\silva\anaconda3\envs\gempy\lib\site-packages\gempy_engine\API\dual_contouring\multi_scalar_dual_contouring.py:47: UserWarning: Fancy triangulation only works with regular grid of resolution [2,2,2]. Defaulting to regular triangulation
#   warnings.warn("Fancy triangulation only works with regular grid of resolution [2,2,2]. Defaulting to regular triangulation")
# Solutions(1 Octree Levels, 9 DualContouringMeshes)

# %%
geo_model.solutions
# Out:
# Solutions(1 Octree Levels, 9 DualContouringMeshes)

# %%
gpv.plot_2d(geo_model, show_data=False, show_scalar=True, show_lith=False)
plt.show()
# Out:
# C:\Users\silva\anaconda3\envs\gempy\lib\site-packages\gempy_viewer\API\_plot_2d_API.py:170: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.fig.show()

# %%
gpv.plot_2d(geo_model, series_n=1, show_data=False, show_scalar=True, show_lith=False)
plt.show()

# %%
gpv.plot_2d(geo_model, show_data=True, cell_number="mid", direction= 'y')

# %%
gpv.plot_3d(geo_model, show_data=False, image=False, plotter_type='basic')
