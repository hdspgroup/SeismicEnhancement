# %% [markdown]
# <div style="text-align: center; color: #ffffff; font-family: Babas; font-size: 3em;">1. SEISMIC LINE - IMBRICATE FAN</div>
# <div style="text-align: left; color: #ffffff; font-family: Babas; font-size: 2.5em;">DESCRIPTION</div>
# <div style="text-align: left; color: #ffffff; font-family: Babas; font-size: 2em; border-bottom: 1px solid white;">The zone worked in this Notebook comes from a N-S oriented cross section worked by Ramos 2020 named "SPAN-2004-4000_psdm_ORIG_VE1"..  The purpose of this example is to show the imbricated fan of faults affecting stratigraphic units interpreted by the author (F9,F5,F4,F2/F1).</div>

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('zone3_model.png')
plt.figure(figsize=(15, 15))
imgplot = plt.imshow(img)
plt.axis('off')
plt.tight_layout()

# %% [markdown]
# # A. CREACIÓN DEL MODELO GEOLÓGICO NUMÉRICO

# %%
import gempy as gp 
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import pyvista
# Out:
# No module named 'osgeo'

# %%
geo_model = gp.create_data('Guajira_Offshore',
                          extent = [0, 9600, 0, 3000, -3500, -1000],
                          resolution = [100, 100, 100],
                          path_o='Orientaciones_RAMOS_GOFF.txt',
                          path_i='Superficies_RAMOS_GOFF.txt')
# Out:
# Active grids: ['regular']

# %%
geo_model.surface_points
# Out:
#              X  Y          Z    smooth  surface
# 0      31.2325  0 -1932.8077  0.000002  fault_2
# 1     431.1913  0 -1678.2145  0.000002  fault_2
# 2     884.0738  0 -1344.8684  0.000002  fault_2
# 3    1292.0906  0 -1064.9933  0.000002  fault_2
# 4      26.3108  0 -2754.0047  0.000002  fault_3
# 5     328.0367  0 -2622.6479  0.000002  fault_3
# 6     858.2322  0 -2406.2448  0.000002  fault_3
# 7    1209.6829  0 -2248.3409  0.000002  fault_3
# 8    1654.3859  0 -1972.9530  0.000002  fault_3
# 9    2293.6074  0 -1515.1320  0.000002  fault_3
# 10   2802.5684  0 -1150.6057  0.000002  fault_3
# 11     30.7337  0 -3370.7892  0.000002  fault_4
# 12    655.6705  0 -3139.9302  0.000002  fault_4
# 13   1142.6550  0 -2909.0719  0.000002  fault_4
# 14   1599.7229  0 -2653.2993  0.000002  fault_4
# 15   2040.5644  0 -2436.9223  0.000002  fault_4
# 16   2610.5401  0 -2113.6862  0.000002  fault_4
# 17   2846.2927  0 -1954.6275  0.000002  fault_4
# 18   3452.0361  0 -1399.8241  0.000002  fault_4
# 19   3721.7012  0 -1245.0799  0.000002  fault_4
# 20     38.5635  0 -3560.0344  0.000002  fault_5
# 21    929.7474  0 -3467.2361  0.000002  fault_5
# 22   1427.1716  0 -3403.6574  0.000002  fault_5
# 23   1950.3767  0 -3310.8230  0.000002  fault_5
# 24   2514.3300  0 -3157.6886  0.000002  fault_5
# 25   3027.8702  0 -2963.6517  0.000002  fault_5
# 26   3777.6857  0 -2649.1490  0.000002  fault_5
# 27   4017.0886  0 -2548.7338  0.000002  fault_5
# 28   4335.3094  0 -2442.0548  0.000002  fault_5
# 29   4698.2278  0 -2320.3915  0.000002  fault_5
# 30   4936.8102  0 -2194.1095  0.000002  fault_5
# 31   5542.0972  0 -1801.5184  0.000002  fault_5
# 1   1928.5807  0 -1754.2756 -5.591929e-01  9.998973e-13  0.829038    0.01  fault_3
# 2   3487.6382  0  -804.4005 -3.746066e-01  9.999312e-13  0.927184    0.01  fault_3
# 3    655.6705  0 -3139.9302 -4.226183e-01  9.999224e-13  0.906308    0.01  fault_4
# 4   2846.2927  0 -1954.6275 -6.427876e-01  9.998819e-13  0.766044    0.01  fault_4
# 5   4228.9909  0  -996.9558 -4.383711e-01  9.999195e-13  0.898794    0.01  fault_4
# 6    929.7474  0 -3467.2361 -8.715574e-02  9.999840e-13  0.996195    0.01  fault_5
# 7   4017.0886  0 -2548.7338 -4.383711e-01  9.999195e-13  0.898794    0.01  fault_5
# 8   6119.4401  0 -1508.1211 -4.383711e-01  9.999195e-13  0.898794    0.01  fault_5
# 9   1633.8930  0 -3480.9217 -1.045285e-01  9.999808e-13  0.994522    0.01  fault_6
# 10  3691.0208  0 -3246.0504 -2.756374e-01  9.999494e-13  0.961262    0.01  fault_6
# 11  6108.4763  0 -2400.3903 -2.191856e-01  9.999597e-13  0.449397    0.01  fault_6
# 12  7493.9887  0 -1638.5050 -8.682409e-02  9.999841e-13  0.492404    0.01  fault_6
# 13  8454.8024  0 -1532.7088 -1.627841e-01  9.999701e-13  0.472759    0.01  fault_6
# 14  9563.1666  0 -2003.6290  1.000000e-12  1.000000e-12  1.010000    0.01       F9
# 15  3014.9052  0 -3006.8485  3.523804e-01  1.000022e-12  0.295682    0.01       F5
# 16  5771.1378  0 -2716.6049 -2.346517e-01  9.999569e-13  1.481533    0.01       F4

# %%
gp.map_stack_to_surfaces(geo_model,
                         {"fault_1":('fault_1'),
                        "fault_2":('fault_2'),
                         "fault_3":('fault_3'),
                        "fault_4":('fault_4'),
                         "fault_5":('fault_5'),
                         "fault_6":('fault_6'),
                        "Strat_Series": ('F10','F9','F5','F4')},
                        remove_unused_series=True)
# Out:
#     surface        series  order_surfaces    color  id
# 0   fault_2       fault_2               1  #015482   1
# 1   fault_3       fault_3               1  #9f0052   2
# 2   fault_4       fault_4               1  #ffbe00   3
# 3   fault_5       fault_5               1  #728f02   4
# 4   fault_6       fault_6               1  #443988   5
# 5        F9  Strat_Series               1  #ff3f20   6
# 6        F5  Strat_Series               2  #5DA629   7
# 7        F4  Strat_Series               3  #4878d0   8
# 8  basement      Basement               1  #ee854a   9

# %%
geo_model.stack
# Out:
#               order_series BottomRelation  isActive  isFault  isFinite
# fault_2                  1        Erosion      True    False     False
# fault_3                  2        Erosion      True    False     False
# fault_4                  3        Erosion      True    False     False
# fault_5                  4        Erosion      True    False     False
# fault_6                  5        Erosion      True    False     False
# Strat_Series             6        Erosion      True    False     False
# Basement                 7        Erosion     False    False     False

# %%
geo_model.rename_surfaces({'basement':'F2/F1'})
# Out:
#    surface        series  order_surfaces    color  id
# 0  fault_2       fault_2               1  #015482   1
# 1  fault_3       fault_3               1  #9f0052   2
# 2  fault_4       fault_4               1  #ffbe00   3
# 3  fault_5       fault_5               1  #728f02   4
# 4  fault_6       fault_6               1  #443988   5
# 5       F9  Strat_Series               1  #ff3f20   6
# 6       F5  Strat_Series               2  #5DA629   7
# 7       F4  Strat_Series               3  #4878d0   8
# 8    F2/F1      Basement               1  #ee854a   9

# %%
geo_model.set_is_fault(['fault_2','fault_3','fault_4','fault_5','fault_6'])
# Out:
# Fault colors changed. If you do not like this behavior, set change_color to False.
# Fault colors changed. If you do not like this behavior, set change_color to False.
#               order_series BottomRelation  isActive  isFault  isFinite
# fault_2                  1          Fault      True     True     False
# fault_3                  2          Fault      True     True     False
# fault_4                  3          Fault      True     True     False
# fault_5                  4          Fault      True     True     False
# fault_6                  5          Fault      True     True     False
# Strat_Series             6        Erosion      True    False     False
# Basement                 7        Erosion     False    False     False

# %%
geo_model.faults.faults_relations_df
# Out:
#               fault_2  fault_3  fault_4  fault_5  fault_6  Strat_Series
# fault_2         False    False    False    False    False          True  \
# fault_3         False    False    False    False    False          True
# fault_4         False    False    False    False    False          True
# fault_5         False    False    False    False    False          True
# fault_6         False    False    False    False    False          True
# Strat_Series    False    False    False    False    False         False
# Basement        False    False    False    False    False         False
#
#               Basement
# fault_2           True
# fault_3           True
# fault_4           True
# fault_5           True
# fault_6           True
# Strat_Series     False
# Basement         False

# %%
geo_model.faults
# Out:
#               order_series BottomRelation  isActive  isFault  isFinite
# fault_2                  1          Fault      True     True     False
# fault_3                  2          Fault      True     True     False
# fault_4                  3          Fault      True     True     False
# fault_5                  4          Fault      True     True     False
# fault_6                  5          Fault      True     True     False
# Strat_Series             6        Erosion      True    False     False
# Basement                 7        Erosion     False    False     False

# %%
geo_model.grid
# Out:
# Grid Object. Values:
# array([[   48. ,    15. , -3487.5],
#        [   48. ,    15. , -3462.5],
#        [   48. ,    15. , -3437.5],
#        ...,
#        [ 9552. ,  2985. , -1062.5],
#        [ 9552. ,  2985. , -1037.5],
#        [ 9552. ,  2985. , -1012.5]])

# %%
gp.set_interpolator(
    geo_model,
    output=['geology'],
    theano_optimizer='fast compile')
# Out:
# Setting kriging parameters to their default values.
# Compiling aesara function...
# Level of Optimization:  fast_compile
# Device:  cpu
# Precision:  float64
# Number of faults:  5
# Compilation Done!
# Kriging values:
#                                  values
# range                     10363.879582
# $C_o$                   2557380.952381
# drift equations  [3, 3, 3, 3, 3, 3, 3]

# %%
gp.get_data(geo_model, 'orientations')
# Out:
#             X  Y          Z           G_x           G_y       G_z  smooth
# 0   1292.0906  0 -1064.9933 -5.446390e-01  9.999000e-13  0.838671    0.01  \
# 1   1928.5807  0 -1754.2756 -5.591929e-01  9.998973e-13  0.829038    0.01
# 2   3487.6382  0  -804.4005 -3.746066e-01  9.999312e-13  0.927184    0.01
# 3    655.6705  0 -3139.9302 -4.226183e-01  9.999224e-13  0.906308    0.01
# 4   2846.2927  0 -1954.6275 -6.427876e-01  9.998819e-13  0.766044    0.01
# 5   4228.9909  0  -996.9558 -4.383711e-01  9.999195e-13  0.898794    0.01
# 6    929.7474  0 -3467.2361 -8.715574e-02  9.999840e-13  0.996195    0.01
# 7   4017.0886  0 -2548.7338 -4.383711e-01  9.999195e-13  0.898794    0.01
# 8   6119.4401  0 -1508.1211 -4.383711e-01  9.999195e-13  0.898794    0.01
# 9   1633.8930  0 -3480.9217 -1.045285e-01  9.999808e-13  0.994522    0.01
# 10  3691.0208  0 -3246.0504 -2.756374e-01  9.999494e-13  0.961262    0.01
# 11  6108.4763  0 -2400.3903 -2.191856e-01  9.999597e-13  0.449397    0.01
# 12  7493.9887  0 -1638.5050 -8.682409e-02  9.999841e-13  0.492404    0.01
# 13  8454.8024  0 -1532.7088 -1.627841e-01  9.999701e-13  0.472759    0.01
# 14  9563.1666  0 -2003.6290  1.000000e-12  1.000000e-12  1.010000    0.01
# 15  3014.9052  0 -3006.8485  3.523804e-01  1.000022e-12  0.295682    0.01
# 16  5771.1378  0 -2716.6049 -2.346517e-01  9.999569e-13  1.481533    0.01
#
#     surface
# 0   fault_2
# 1   fault_3
# 2   fault_3
# 3   fault_4
# 4   fault_4
# 5   fault_4
# 6   fault_5
# 7   fault_5
# 8   fault_5
# 9   fault_6
# 10  fault_6
# 11  fault_6
# 12  fault_6
# 13  fault_6
# 14       F9
# 15       F5
# 16       F4

# %%
gp.plot_2d(geo_model, show_data=True)
plt.show()
# Out:
# /home/ana/anaconda3/envs/gempyv2/lib/python3.10/site-packages/gempy/plot/plot_api.py:261: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.fig.show()

# %%
#gpv = gp.plot_3d(geo_model, image=False, plotter_type='basic')

# %%
gp.get_data(geo_model, 'kriging')
# Out:
#                                 values
# range                     10363.879582
# $C_o$                   2557380.952381
# drift equations  [3, 3, 3, 3, 3, 3, 3]

# %%
sol = gp.compute_model(geo_model)

# %%
geo_model.solutions
# Out:
# Lithology ids
#   [8. 8. 8. ... 6. 6. 6.]

# %% [markdown]
# ### 2D MODEL SECTION

# %%
######
gp.plot_2d(geo_model, show_data=True)
plt.savefig('section_2D.png', dpi=300, bbox_inches='tight')
plt.show()
######
# Out:
# /home/ana/anaconda3/envs/gempyv2/lib/python3.10/site-packages/gempy/plot/plot_api.py:261: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.fig.show()

# %%
gp.plot_2d(geo_model, show_data=False, show_scalar=True, show_lith=False)
plt.show()

# %%
gp.plot_2d(geo_model, series_n=1, show_data=True, show_scalar=True, show_lith=False, legend=False)
plt.show()
# Out:
# /home/ana/anaconda3/envs/gempyv2/lib/python3.10/site-packages/gempy/plot/visualization_2d.py:353: UserWarning: The following kwargs were not used by contour: 'legend'
#   ax.contour(image, cmap='autumn', extent=extent_val, zorder=8, **kwargs)
# /home/ana/anaconda3/envs/gempyv2/lib/python3.10/site-packages/gempy/plot/visualization_2d.py:356: UserWarning: The following kwargs were not used by contour: 'legend'
#   ax.contourf(image, cmap='autumn', extent=extent_val, zorder=7, alpha=.8,
# /home/ana/anaconda3/envs/gempyv2/lib/python3.10/site-packages/gempy/plot/plot_api.py:261: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.fig.show()

# %% [markdown]
# ### 3D GEOLOGICAL MODEL

# %%
ver, sim = gp.get_surfaces(geo_model)
gpv = gp.plot_3d(geo_model, image=False, plotter_type='basic', notebook=True)
# Out:
# C:\Users\alfac\anaconda3\envs\gempy2.3.1\lib\site-packages\pyvista\jupyter\notebook.py:58: UserWarning: Failed to use notebook backend:
#
# No module named 'trame'
#
# Falling back to a static output.
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=1024x768>

# %%
# save 3D model
import pickle
pickle.dump(geo_model, open("ramos_GOFF.p", "wb"))

# %%
# load the model to check its ok
modelo = pickle.load(open("ramos_GOFF.p", "rb"))

# %% [markdown]
# # B. ASSIGNMENT OF GEOPHYSICAL PROPERTIES

# %%
modelo.surfaces
# Out:
#    surface        series  order_surfaces    color  id
# 0  fault_2       fault_2               1  #527682   1
# 1  fault_3       fault_3               1  #527682   2
# 2  fault_4       fault_4               1  #527682   3
# 3  fault_5       fault_5               1  #527682   4
# 4  fault_6       fault_6               1  #527682   5
# 5       F9  Strat_Series               1  #ff3f20   6
# 6       F5  Strat_Series               2  #5DA629   7
# 7       F4  Strat_Series               3  #4878d0   8
# 8    F2/F1      Basement               1  #ee854a   9

# %%
# assign geophysics properties
modelo.add_surface_values([1500, 1500, 1500, 1500, 1500, 2000, 2500, 3000, 3500], ['vp'])  #m/s vp
#modelo.add_surface_values([2.5, 2.5, 2.5, 2.5, 2.5, 2.5, 2.8, 3.2, 3.6], ['density'])  #g/cm3 density
modelo.surfaces
# Out:
#    surface        series  order_surfaces    color  id    vp
# 0  fault_2       fault_2               1  #527682   1  1500
# 1  fault_3       fault_3               1  #527682   2  1500
# 2  fault_4       fault_4               1  #527682   3  1500
# 3  fault_5       fault_5               1  #527682   4  1500
# 4  fault_6       fault_6               1  #527682   5  1500
# 5       F9  Strat_Series               1  #ff3f20   6  2000
# 6       F5  Strat_Series               2  #5DA629   7  2500
# 7       F4  Strat_Series               3  #4878d0   8  3000
# 8    F2/F1      Basement               1  #ee854a   9  3500

# %%
p3d = gp.plot_3d(modelo, notebook=True)
p3d.plot_data()

sol = gp.compute_model(modelo)

p3d.plot_surfaces()
# Plot the lithological units
p3d.plot_structured_grid('lith')
# Out:
# /home/ana/anaconda3/envs/gempyv2/lib/python3.10/site-packages/pyvista/jupyter/notebook.py:58: UserWarning: Failed to use notebook backend:
#
# No module named 'trame'
#
# Falling back to a static output.
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=1024x768>
# [StructuredGrid (0x7c7d246d6c20)
#    N Cells:      970299
#    N Points:     1000000
#    X Bounds:     4.800e+01, 9.552e+03
#    Y Bounds:     1.500e+01, 2.985e+03
#    Z Bounds:     -3.488e+03, -1.012e+03
#    Dimensions:   100, 100, 100
#    N Arrays:     1,
#  <matplotlib.colors.ListedColormap at 0x7c7d27441570>]

# %%
sol.values_matrix #compute geophysics properties
# Out:
# array([[3000., 3000., 3000., ..., 2000., 2000., 2000.]])

# %%
# Reshaping our data 
import numpy as np
shape = [100,100,100]
reshaped = np.reshape(sol.values_matrix, shape, order='C')
modelo_propiedades = np.flip(reshaped, axis=2).T
modelo_propiedades.shape
# Out:
# (100, 100, 100)

# %%
plt.imshow(modelo_propiedades[:,49,:], cmap='viridis')

# %%
#np.save('densidad.npy', modelo_propiedades)
np.save('vp.npy', modelo_propiedades)

# %%
#xp =np.load('densidad.npy')
xp =np.load('vp.npy')

# %%
import matplotlib.pyplot as plt


plt.imshow(xp[:,0,:], cmap='viridis', extent=[0, 9600, 0, 3000, -3500, -1000])
plt.title('Velocidad de Onda P (m/s)')
#plt.title('Densidad (g/cm3)')
plt.colorbar(location="bottom", shrink=0.5)
plt.savefig('vp.png', dpi=300, bbox_inches='tight')
#plt.savefig('densidad.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # C. ERROR PROPAGATION WITH MONTE CARLO METHOD

# %%
geo_model.surfaces
# Out:
#    surface        series  order_surfaces    color  id
# 0  fault_2       fault_2               1  #527682   1
# 1  fault_3       fault_3               1  #527682   2
# 2  fault_4       fault_4               1  #527682   3
# 3  fault_5       fault_5               1  #527682   4
# 4  fault_6       fault_6               1  #527682   5
# 5       F9  Strat_Series               1  #ff3f20   6
# 6       F5  Strat_Series               2  #5DA629   7
# 7       F4  Strat_Series               3  #4878d0   8
# 8    F2/F1      Basement               1  #ee854a   9

# %%
indices_bool = geo_model.surface_points.df['surface'].isin(['F9','F5','F4','F2/F1'])

# %%
indices = geo_model.surface_points.df.index[indices_bool]
indices
# Out:
# Index([ 56,  57,  58,  59,  60,  61,  62,  63,  64,  65,
#        ...
#        172, 173, 174, 175, 176, 177, 178, 179, 180, 181],
#       dtype='int64', length=126)

# %%
Z_init = geo_model.surface_points.df.loc[(indices, ['Z', 'surface'])].copy()

# %%
df = pd.DataFrame(Z_init)

# %%
# Filter DataFrame
capa1 = df[df['surface'] == 'F9']['Z']
capa2 = df[df['surface'] == 'F5']['Z']
capa3 = df[df['surface'] == 'F4']['Z']
capa4 = df[df['surface'] == 'F2/F1']['Z']

# %%
def sample(silent=True):
    Z_var = np.random.normal(0, 30, size=4)
    Z_loc = np.hstack([capa1 + Z_var[0],
                       capa2 + Z_var[1],
                       capa3 + Z_var[2],
                       capa4 + Z_var[3]])
    
    if silent:
        geo_model.modify_surface_points(indices, Z=Z_loc)
        gp.compute_model(geo_model)
    else:
        # Create an object
        plot_object = gp.plot_2d(geo_model)
        
        # Pass the object as argument of modify_surface_points
        geo_model.modify_surface_points(indices, Z=Z_loc, plot_object=plot_object)
    
    return geo_model.solutions.lith_block

# %%
lith_blocks = np.array([])
n_iterations = 10  # Number of iterations

for i in range(n_iterations):
    lith_blocks = np.append(lith_blocks, sample())

# %%
lith_blocks = lith_blocks.reshape(n_iterations, -1)
lith_blocks.shape, lith_blocks
# Out:
# ((10, 1000000),
#  array([[8., 8., 8., ..., 6., 6., 6.],
#         [8., 8., 8., ..., 6., 6., 6.],
#         [7., 7., 7., ..., 6., 6., 6.],
#         ...,
#         [8., 8., 8., ..., 6., 6., 6.],
#         [8., 8., 8., ..., 6., 6., 6.],
#         [8., 8., 8., ..., 6., 6., 6.]]))

# %%
from gempy.bayesian.fields import compute_prob, calculate_ie_masked
prob_block = compute_prob(lith_blocks)
# Out:
# /home/ana/anaconda3/envs/gempyv2/lib/python3.10/site-packages/gempy/bayesian/fields.py:8: UserWarning: This function is Deprecated, please use the probability function instead
#   warnings.warn("This function is Deprecated, please use the probability function instead")

# %%
layer = 0
p2dp = gp.plot_2d(geo_model,
                  show_lith=False, show_boundaries=False,
                  show_data=False,
                  regular_grid=prob_block[layer],
                  kwargs_regular_grid={'cmap': 'viridis', 'norm': None})

prob_min = prob_block[layer].min()  # Minimum value of probability
prob_max = prob_block[layer].max()  # Maximum value of probability

# Create some sample data
data = np.random.rand(50, 50)

# Create plot
mappable = plt.imshow(data, cmap='viridis')
plt.title('Facie 9')
colorbar = plt.colorbar(mappable, shrink=0.3)
colorbar.set_ticks([0, 1])  # Define ticks location
colorbar.set_label('Probabilidad de la capa')  

# Save plot
plt.savefig('Probabilidad_F9_GOFF.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# /home/ana/anaconda3/envs/gempyv2/lib/python3.10/site-packages/gempy/plot/plot_api.py:261: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.fig.show()

# %%
layer = 1
p2dp = gp.plot_2d(geo_model,
                  show_lith=False, show_boundaries=False,
                  show_data=False,
                  regular_grid=prob_block[layer],
                  kwargs_regular_grid={'cmap': 'viridis', 'norm': None})

prob_min = prob_block[layer].min()  # Minimum value of probability
prob_max = prob_block[layer].max()  # Maximum value of probability

# Create some sample data
data = np.random.rand(50, 50)

# Create plot
mappable = plt.imshow(data, cmap='viridis')
plt.title('Facie 5')
colorbar = plt.colorbar(mappable, shrink=0.3)
colorbar.set_ticks([0, 1])  # Define ticks location
colorbar.set_label('Probabilidad de la capa')  

# Save plot
plt.savefig('Probabilidad_F5_GOFF.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
layer = 2
p2dp = gp.plot_2d(geo_model,
                  show_lith=False, show_boundaries=False,
                  show_data=False,
                  regular_grid=prob_block[layer],
                  kwargs_regular_grid={'cmap': 'viridis', 'norm': None})

prob_min = prob_block[layer].min()  # Minimum value of probability
prob_max = prob_block[layer].max()  # Maximum value of probability

# Create some sample data
data = np.random.rand(50, 50)

# Create plot
mappable = plt.imshow(data, cmap='viridis')
plt.title('Facie 4')
colorbar = plt.colorbar(mappable, shrink=0.3)
colorbar.set_ticks([0, 1])  # Define ticks location
colorbar.set_label('Probabilidad de la capa')  

# Save plot
plt.savefig('Probabilidad_F4_GOFF.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
layer = 3
p2dp = gp.plot_2d(geo_model,
                  show_lith=False, show_boundaries=False,
                  show_data=False,
                  regular_grid=prob_block[layer],
                  kwargs_regular_grid={'cmap': 'viridis', 'norm': None})

prob_min = prob_block[layer].min()  # Minimum value of probability
prob_max = prob_block[layer].max()  # Maximum value of probability

# Create some sample data
data = np.random.rand(50, 50)

# Create plot
mappable = plt.imshow(data, cmap='viridis')
plt.title('Facie 2/1')
colorbar = plt.colorbar(mappable, shrink=0.3)
colorbar.set_ticks([0, 1])  # Define ticks location
colorbar.set_label('Probabilidad de la capa')  

# Save plot
plt.savefig('Probabilidad_F21_GOFF.png', dpi=300, bbox_inches='tight')
plt.show()
